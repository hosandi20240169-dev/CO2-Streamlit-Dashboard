# %% [markdown]
# <a href="https://colab.research.google.com/github/hosandi20240169-dev/CO2-Streamlit-Dashboard/blob/main/Datasciencedatacleaningbook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.listdir('/content/drive/MyDrive/DataScienceCW')
# Out:
# ['P_CO2 Emissions.xlsx']

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/DataScienceCW/P_CO2 Emissions.xlsx'

df = pd.read_excel(file_path, skiprows=4)

df.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1                      Andorra          AND
# 2  Africa Eastern and Southern          AFE
# 3                  Afghanistan          AFG
# 4   Africa Western and Central          AFW
#
#                            Indicator Name  Indicator Code         1960  \
# 0  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  2660.110136
# 1  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC          NaN
# 2  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC     4.530298
# 3  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC     4.470474
# 4  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC     0.454398
#
#           1961         1962         1963         1964         1965  ...  \
# 0  2714.756817  2939.390272  2792.344200  2699.048789  2407.690195  ...
# 1          NaN          NaN          NaN          NaN          NaN  ...
# ...

# %%
df.columns = df.columns.str.strip()

# %%
df = df.dropna(how='all')

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 70 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    292 non-null    object
#  1   Country Code    292 non-null    object
#  2   Indicator Name  292 non-null    object
#  3   Indicator Code  292 non-null    object
#  4   nan             244 non-null    float64
#  5   nan             244 non-null    float64
#  6   nan             245 non-null    float64
#  7   nan             245 non-null    float64
#  8   nan             249 non-null    float64
#  9   nan             250 non-null    float64
#  10  nan             250 non-null    float64
#  11  nan             250 non-null    float64
#  12  nan             250 non-null    float64
#  13  nan             250 non-null    float64
#  14  nan             254 non-null    float64
#  15  nan             254 non-null    float64
#  16  nan             254 non-null    float64
# ...

# %%
df_long = df.melt(
    id_vars=["Country Name", "Country Code"],
    var_name="Year",
    value_name="CO2"
)

df_long.head()
# Out:
#                   Country Name Country Code            Year  \
# 0                        Aruba          ABW  Indicator Name
# 1                      Andorra          AND  Indicator Name
# 2  Africa Eastern and Southern          AFE  Indicator Name
# 3                  Afghanistan          AFG  Indicator Name
# 4   Africa Western and Central          AFW  Indicator Name
#
#                                       CO2
# 0  CO2 emissions (metric tons per capita)
# 1  CO2 emissions (metric tons per capita)
# 2  CO2 emissions (metric tons per capita)
# 3  CO2 emissions (metric tons per capita)
# 4  CO2 emissions (metric tons per capita)

# %%
df_long = df_long.dropna()

# %%
df_long.to_csv('/content/drive/MyDrive/DataScienceCW/cleaned_co2.csv', index=False)
